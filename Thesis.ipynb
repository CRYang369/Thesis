# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
from collections import OrderedDict

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
arrhyData=pd.read_csv('arrhythmia data with title.csv')

# %%
arrhyData.head()
# Out:
#    Age  Sex  Height  Weight  QRS duration  P-R interval  Q-T interval  \
# 0   75    0     190      80            91           193           371
# 1   56    1     165      64            81           174           401
# 2   54    0     172      95           138           163           386
# 3   55    0     175      94           100           202           380
# 4   75    0     190      80            88           181           360
#
#    T interval  P interval  QRS  ... Q wave V6 R wave V6 S wave V6 R' wave V6  \
# 0         174         121  -16  ...       0.0       9.0      -0.9        0.0
# 1         149          39   25  ...       0.0       8.5       0.0        0.0
# 2         185         102   96  ...       0.0       9.5      -2.4        0.0
# 3         179         143   28  ...       0.0      12.2      -2.2        0.0
# 4         177         103  -16  ...       0.0      13.1      -3.6        0.0
#
#   S' wave V6  P wave V6  T wave V6  QRSA V6  QRSTA V6  label
# 0        0.0        0.9        2.9     23.3      49.4      8
# 1        0.0        0.2        2.1     20.4      38.8      6
# 2        0.0        0.3        3.4     12.3      49.0     10
# 3        0.0        0.4        2.6     34.6      61.6      1
# 4        0.0       -0.1        3.9     25.4      62.8      7
#
# [5 rows x 280 columns]

# %%
arrhyData.describe()
# Out:
#               Age         Sex      Height      Weight  QRS duration  \
# count  452.000000  452.000000  452.000000  452.000000    452.000000
# mean    46.471239    0.550885  166.188053   68.170354     88.920354
# std     16.466631    0.497955   37.170340   16.590803     15.364394
# min      0.000000    0.000000  105.000000    6.000000     55.000000
# 25%     36.000000    0.000000  160.000000   59.000000     80.000000
# 50%     47.000000    1.000000  164.000000   68.000000     86.000000
# 75%     58.000000    1.000000  170.000000   79.000000     94.000000
# max     83.000000    1.000000  780.000000  176.000000    188.000000
#
#        P-R interval  Q-T interval  T interval  P interval         QRS  ...  \
# count    452.000000    452.000000  452.000000  452.000000  452.000000  ...
# mean     155.152655    367.207965  169.949115   90.004425   33.676991  ...
# std       44.842283     33.385421   35.633072   25.826643   45.431434  ...
# min        0.000000    232.000000  108.000000    0.000000 -172.000000  ...
# 25%      142.000000    350.000000  148.000000   79.000000    3.750000  ...
# 50%      157.000000    367.000000  162.000000   91.000000   40.000000  ...
# 75%      175.000000    384.000000  179.000000  102.000000   66.000000  ...
# max      524.000000    509.000000  381.000000  205.000000  169.000000  ...
#
#         Q wave V6   R wave V6   S wave V6  R' wave V6  S' wave V6   P wave V6  \
# count  452.000000  452.000000  452.000000  452.000000       452.0  452.000000
# mean    -0.278982    9.048009   -1.457301    0.003982         0.0    0.514823
# std      0.548876    3.472862    2.002430    0.050118         0.0    0.347531
# min     -4.100000    0.000000  -28.600000    0.000000         0.0   -0.800000
# 25%     -0.425000    6.600000   -2.100000    0.000000         0.0    0.400000
# 50%      0.000000    8.800000   -1.100000    0.000000         0.0    0.500000
# 75%      0.000000   11.200000    0.000000    0.000000         0.0    0.700000
# max      0.000000   23.600000    0.000000    0.800000         0.0    2.400000
#
#         T wave V6     QRSA V6    QRSTA V6       label
# count  452.000000  452.000000  452.000000  452.000000
# mean     1.222345   19.326106   29.473230    3.880531
# std      1.426052   13.503922   18.493927    4.407097
# min     -6.000000  -44.200000  -38.600000    1.000000
# 25%      0.500000   11.450000   17.550000    1.000000
# 50%      1.350000   18.100000   27.900000    1.000000
# 75%      2.100000   25.825000   41.125000    6.000000
# max      6.000000   88.800000  115.900000   16.000000
#
# [8 rows x 275 columns]

# %%
arrhyData.describe().T
# Out:
#               count        mean        std    min     25%     50%      75%  \
# Age           452.0   46.471239  16.466631    0.0   36.00   47.00   58.000
# Sex           452.0    0.550885   0.497955    0.0    0.00    1.00    1.000
# Height        452.0  166.188053  37.170340  105.0  160.00  164.00  170.000
# Weight        452.0   68.170354  16.590803    6.0   59.00   68.00   79.000
# QRS duration  452.0   88.920354  15.364394   55.0   80.00   86.00   94.000
# ...             ...         ...        ...    ...     ...     ...      ...
# P wave V6     452.0    0.514823   0.347531   -0.8    0.40    0.50    0.700
# T wave V6     452.0    1.222345   1.426052   -6.0    0.50    1.35    2.100
# QRSA V6       452.0   19.326106  13.503922  -44.2   11.45   18.10   25.825
# QRSTA V6      452.0   29.473230  18.493927  -38.6   17.55   27.90   41.125
# label         452.0    3.880531   4.407097    1.0    1.00    1.00    6.000
#
#                 max
# Age            83.0
# Sex             1.0
# Height        780.0
# Weight        176.0
# QRS duration  188.0
# ...             ...
# P wave V6       2.4
# T wave V6       6.0
# QRSA V6        88.8
# QRSTA V6      115.9
# label          16.0
#
# [275 rows x 8 columns]

# %%
fig=plt.figure(figsize=(16,5))

# %%
df1=arrhyData[arrhyData["Sex"]==1]

# %%
df1.shape
# Out:
# (249, 280)

# %%
df2=arrhyData[arrhyData["Sex"]==0]

# %%
df2.shape
# Out:
# (203, 280)

# %%
arrhyData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Columns: 280 entries, Age to label
# dtypes: float64(120), int64(155), object(5)
# memory usage: 988.9+ KB

# %%
arrhyData.tail()
# Out:
#      Age  Sex  Height  Weight  QRS duration  P-R interval  Q-T interval  \
# 447   53    1     160      70            80           199           382
# 448   37    0     190      85           100           137           361
# 449   36    0     166      68           108           176           365
# 450   32    1     155      55            93           106           386
# 451   78    1     160      70            79           127           364
#
#      T interval  P interval  QRS  ... Q wave V6 R wave V6 S wave V6  \
# 447         154         117  -37  ...       0.0       4.3      -5.0
# 448         201          73   86  ...       0.0      15.6      -1.6
# 449         194         116  -85  ...       0.0      16.3     -28.6
# 450         218          63   54  ...      -0.4      12.0      -0.7
# 451         138          78   28  ...       0.0      10.4      -1.8
#
#     R' wave V6 S' wave V6  P wave V6  T wave V6  QRSA V6  QRSTA V6  label
# 447        0.0        0.0        0.7        0.6     -4.4      -0.5      1
# 448        0.0        0.0        0.4        2.4     38.0      62.4     10
# 449        0.0        0.0        1.5        1.0    -44.2     -33.2      2
# 450        0.0        0.0        0.5        2.4     25.0      46.6      1
# 451        0.0        0.0        0.5        1.6     21.3      32.8      1
#
# [5 rows x 280 columns]

# %%
arrhyData.groupby("label").describe()
# Out:
#          Age                                                        Sex  \
#        count       mean        std   min   25%   50%   75%   max  count
# label
# 1      245.0  46.273469  14.556092   9.0  36.0  46.0  57.0  83.0  245.0
# 2       44.0  51.750000  14.160418  17.0  44.0  55.0  62.0  79.0   44.0
# 3       15.0  53.333333  11.286317  33.0  45.5  50.0  63.5  70.0   15.0
# 4       15.0  57.266667  11.895177  40.0  50.0  57.0  63.5  80.0   15.0
# 5       13.0  30.846154  27.904140   0.0   3.0  34.0  53.0  73.0   13.0
# 6       25.0  47.920000  13.165359  29.0  37.0  46.0  56.0  74.0   25.0
# 7        3.0  60.666667  18.339393  40.0  53.5  67.0  71.0  75.0    3.0
# 8        2.0  71.000000   5.656854  67.0  69.0  71.0  73.0  75.0    2.0
# 9        9.0  58.222222  21.211894   7.0  61.0  66.0  68.0  75.0    9.0
# 10      50.0  38.920000  17.692198   7.0  27.0  38.5  54.0  73.0   50.0
# 14       4.0  19.500000  11.090537   9.0  12.0  17.5  25.0  34.0    4.0
# 15       5.0  57.400000   6.188699  49.0  55.0  58.0  59.0  66.0    5.0
# 16      22.0  44.272727  19.644900   8.0  35.5  43.5  53.5  78.0   22.0
#
#                  ... QRSA V6       QRSTA V6                              \
#            mean  ...     75%   max    count       mean        std   min
# label            ...
# 1      0.653061  ...  26.400  56.4    245.0  33.836735  16.068479  -0.5
# 2      0.590909  ...  30.400  47.2     44.0  13.795455  15.901835 -33.2
# 3      0.000000  ...  16.850  24.6     15.0  11.993333  20.006551 -38.6
# 4      0.266667  ...  17.450  24.1     15.0  12.206667   5.719699   2.2
# 5      0.692308  ...  12.000  25.0     13.0  15.646154  19.755278 -20.1
# 6      0.440000  ...  26.100  44.5     25.0  33.804000  13.299075  15.2
# 7      0.000000  ...  26.700  28.0      3.0  33.133333  26.736554  10.9
# 8      0.000000  ...  14.475  23.3      2.0  23.650000  36.415999  -2.1
# 9      0.555556  ...  67.900  88.8      9.0  31.055556  36.057111  -2.4
# 10     0.440000  ...  22.650  38.0     50.0  33.550000  16.011517   4.4
# 14     0.250000  ...  46.500  54.0      4.0  42.950000  20.483571  22.4
# 15     0.800000  ...  18.200  30.2      5.0  16.980000  13.514141  -0.8
# 16     0.318182  ...  25.325  49.9     22.0  29.681818  19.178153 -25.4
#
#
#           25%    50%     75%    max
# label
# 1      22.200  31.70  44.600   97.6
# 2       6.675  11.80  21.925   47.8
# 3       7.100  19.30  21.900   42.0
# 4       8.800  12.00  15.400   22.4
# 5       5.400  10.70  23.500   60.4
# 6      27.000  30.60  46.700   59.6
# 7      18.300  25.70  44.250   62.8
# 8      10.775  23.65  36.525   49.4
# 9       8.400  27.00  43.700  115.9
# 10     23.850  30.10  41.250   84.4
# 14     28.925  40.50  54.525   68.4
# 15     12.800  16.00  20.300   36.6
# 16     18.050  33.20  42.625   61.6
#
# [13 rows x 2192 columns]

# %%
arrhyData.groupby("Sex").describe()
# Out:
#        Age                                                    Height  \
#      count       mean        std  min   25%   50%   75%   max  count
# Sex
# 0    203.0  47.546798  16.519761  0.0  37.5  47.0  59.0  80.0  203.0
# 1    249.0  45.594378  16.404173  1.0  34.0  46.0  58.0  83.0  249.0
#
#                  ... QRSTA V6         label                                \
#            mean  ...      75%    max  count      mean       std  min  25%
# Sex              ...
# 0    171.315271  ...     40.3  115.9  203.0  4.748768  4.744036  1.0  1.0
# 1    162.008032  ...     41.3   73.0  249.0  3.172691  3.983623  1.0  1.0
#
#
#      50%  75%   max
# Sex
# 0    2.0  8.5  16.0
# 1    1.0  4.0  16.0
#
# [2 rows x 2192 columns]

# %%
sns.countplot(x='label',data=arrhyData)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
sns.boxplot(x='label',y='Sex',data=arrhyData)
# Out:
# <AxesSubplot:xlabel='label', ylabel='Sex'>

# %%
sns.boxplot(x='label',y='Age',data=arrhyData)
# Out:
# <AxesSubplot:xlabel='label', ylabel='Age'>

# %%
sns.boxplot(x='label',y='Height',data=arrhyData)
# Out:
# <AxesSubplot:xlabel='label', ylabel='Height'>

# %%
sns.boxplot(x='label',y='Weight',data=arrhyData)
# Out:
# <AxesSubplot:xlabel='label', ylabel='Weight'>

# %%
arrhyData.label>1
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 447    False
# 448     True
# 449     True
# 450    False
# 451    False
# Name: label, Length: 452, dtype: bool

# %%
arrhyData.label==1
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 447     True
# 448    False
# 449    False
# 450     True
# 451     True
# Name: label, Length: 452, dtype: bool

# %%
type=pd.value_counts(arrhyData['label']==1)

# %%
sns.countplot(x=type,data=arrhyData)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
sns.boxplot(x=range(normal arrhythmia),data=arrhyData )
# Out:
#   File "C:\Users\COOLER~1\AppData\Local\Temp/ipykernel_6672/2041275893.py", line 1
#     sns.boxplot(x=range(normal arrhythmia),data=arrhyData )
#                                ^
# SyntaxError: invalid syntax

# %%
if('label'==1):
    kind='normal'
else:
    kind='arrythmia'

# %%
sns.countplot(x='kind',data=arrhyData)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\COOLER~1\AppData\Local\Temp/ipykernel_6672/822028594.py in <module>
# ----> 1 sns.countplot(x='kind',data=arrhyData)
#
# B:\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# B:\Anaconda\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
#    3600         estimator, ci, n_boot, units, seed,
#
# B:\Anaconda\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# B:\Anaconda\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'kind'

# %%
#相关系数矩阵
rDf=examDf.corr()
rDf
# Out:
#           学习时间        分数
# 学习时间  1.000000  0.923985
# 分数    0.923985  1.000000

# %%
#将训练集特征转化为二维数组**行1列
X_train=X_train.reshape(-1,1)
#将测试集特征转化为二维数组**行1列
X_test=X_test.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\COOLER~1\AppData\Local\Temp/ipykernel_3288/2390919168.py in <module>
#       1 #将训练集特征转化为二维数组**行1列
# ----> 2 X_train=X_train.reshape(-1,1)
#       3 #将测试集特征转化为二维数组**行1列
#       4 X_test=X_test.reshape(-1,1)
#
# B:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reshape'
